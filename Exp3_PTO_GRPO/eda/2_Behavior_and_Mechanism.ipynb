# %% [markdown]
# # 2 · Behavior & Mechanism  `[EVAL]`
#
# How the therapist's behaviour changes over training, and whether the score gains are real MI skill or a
# style shift (more praise, fewer questions, longer turns). All from the full eval conversations; every
# view runs for both methods / all arms.

# %%
import sys, os; sys.path.insert(0, os.path.abspath("."))           # cwd = eda/ -> `import exp3`
import warnings; warnings.filterwarnings("ignore")
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
pd.set_option("display.width", 185, "display.max_columns", 50)
import exp3
from exp3 import stats, behavior, training, pref, figures, plots
S = exp3.notebook_setup()      # S.ARMS, S.SCORES, S.PALETTE, S.METRICS, S.ORACLE_NOISE, S.RESULTS_DIR
# Out:
# arms on disk: [('PTO_LA0', 11), ('PTO_LA5', 6), ('GRPO_LA0', 6), ('GRPO_LA5', 2)]
# scores_long: (16128, 19) | arms scored: ['GRPO_LA0', 'GRPO_LA5', 'PTO_LA0', 'PTO_LA5']
# exports -> C:\Users\baruc\Desktop\Projects\Thesis_PTO_GRPO\Exp3_PTO_GRPO\eda\results

# %%
BEH = behavior.behavior_by_iter(S.ARMS)

# %% [markdown]
# ## 1 · Behaviour drift  `[EVAL]`
# **Purpose.** MITI counts (questions B3_Q, reflections B4_SR/B5_CR, affirmations B6_AF) + text metrics
# across iterations, per arm. **Read:** B6_AF + turn length rising while B3_Q falls = the
# affirmation/advice drift (warmth over skill).

# %%
fig = plots.behavior_trajectory_grid(BEH)
if fig: exp3.save_fig(fig, "behavior_drift", caption="MITI behavior counts (B3_Q questions, B4_SR/B5_CR reflections, B6_AF affirmations, B2_Persuade) + text metrics across iterations, all arms."); plt.show()
BM = [m for m in ["B3_Q", "B4_SR", "B5_CR", "B6_AF", "B2_Persuade", "RtoQ", "Empathy", "loop", "affirm_rate"] if m in BEH.columns]
for arm in sorted(BEH.arm.unique()):
    BT = BEH[BEH.arm == arm][["iteration"] + BM].round(3)
    print(f"\n=== {arm} behavior by iteration ==="); display(BT)
    exp3.save_table(BT, f"{arm}_behavior_by_iter", caption=f"{arm} mean behavior metrics per iteration (MITI counts + text metrics).")
# Out:
# === GRPO_LA0 behavior by iteration ===
#    iteration   B3_Q  B4_SR  B5_CR  B6_AF  B2_Persuade   RtoQ  Empathy   loop  affirm_rate
# 0          0  6.385  2.698  1.365  0.521        1.167  0.700    3.469  0.479        0.029
# 1          1  5.573  2.271  1.062  0.385        1.302  0.632    3.521  0.365        0.039
# 2          2  6.594  3.104  1.635  0.594        1.427  0.741    3.792  0.354        0.016
# 3          3  5.396  2.427  1.365  0.479        1.802  0.673    4.167  0.000        0.014
# 4          4  5.542  2.677  1.531  0.906        2.146  0.732    4.302  0.042        0.016
# 5          5  5.396  2.792  1.448  0.865        2.125  0.776    4.219  0.021        0.046
# === GRPO_LA5 behavior by iteration ===
#    iteration   B3_Q  B4_SR  B5_CR  B6_AF  B2_Persuade   RtoQ  Empathy   loop  affirm_rate
# 6          0  6.552  2.896  1.292  0.417        1.042  0.765    3.458  0.490        0.050
# 7          1  6.125  2.490  1.260  0.438        1.333  0.656    3.646  0.354        0.046
# === PTO_LA0 behavior by iteration ===
#     iteration   B3_Q  B4_SR  B5_CR  B6_AF  B2_Persuade   RtoQ  Empathy   loop  affirm_rate
# 8           0  6.448  2.656  1.302  0.417        1.281  0.610    3.448  0.490        0.031
# 9           1  5.802  2.562  1.271  0.427        1.094  0.612    3.698  0.375        0.037
# 10          2  5.854  2.677  1.271  0.479        1.552  0.764    3.833  0.271        0.040
# 11          3  4.958  2.281  1.229  0.427        1.573  0.673    4.010  0.104        0.041
# 12          4  4.635  2.104  1.198  0.646        1.708  0.650    4.198  0.042        0.041
# 13          5  4.615  1.958  1.073  0.521        1.781  0.607    4.260  0.010        0.054
# 14          6  4.417  1.896  1.073  0.844        1.677  0.652    4.427  0.010        0.107
# 15          7  4.458  1.865  1.052  1.115        1.708  0.606    4.396  0.010        0.188
# 16          8  3.938  1.885  1.156  1.073        1.583  0.798    4.531  0.010        0.282
# 17          9  3.594  1.646  1.052  1.365        1.562  0.727    4.573  0.000        0.415
# 18         10  3.844  1.698  1.125  1.635        1.562  0.750    4.615  0.000        0.456
# === PTO_LA5 behavior by iteration ===
#     iteration   B3_Q  B4_SR  B5_CR  B6_AF  B2_Persuade   RtoQ  Empathy   loop  affirm_rate
# 19          0  7.229  2.719  1.312  0.542        1.281  0.728    3.448  0.448        0.036
# 20          1  6.010  2.635  1.260  0.354        1.094  0.626    3.510  0.427        0.053
# 21          2  5.271  2.615  1.427  0.490        1.635  0.764    3.740  0.417        0.035
# 22          3  5.062  2.396  1.396  0.479        1.615  0.682    3.938  0.219        0.027
# 23          4  4.490  1.875  1.021  0.510        1.677  0.589    4.146  0.115        0.046

# %% [markdown]
# ## 2 · Rubric factor structure  `[EVAL]`
# **Purpose.** Are the 6 rubrics independent skills or one factor? Inter-rubric correlation + per-arm PC1
# share. **Read:** a dominant PC1 means "all rubrics up" is one latent warmth/satisfaction axis. (Reward
# faithfulness lives in `4_Reward_Reliability`.)

# %%
fig = plots.rubric_correlation_heatmap(S.SCORES)
exp3.save_fig(fig, "rubric_correlation", caption="Spearman correlation among the rubric scores (per conversation, pooled)."); plt.show()
for arm in sorted(S.SCORES.arm.unique()):
    p = stats.rubric_pca(S.SCORES[S.SCORES.arm == arm])
    if p["explained_variance_ratio"]:
        print(f"{arm}: PC1 = {p['explained_variance_ratio'][0]:.1%}  loadings={p['pc1_loadings']}")
# Out:
# GRPO_LA0: PC1 = 92.1%  loadings={'Q1Q2': 0.447, 'WAI-SR': 0.45, 'CSQ-8': 0.451, 'MI-SAT': 0.456, 'MITI': 0.433}
# GRPO_LA5: PC1 = 93.3%  loadings={'Q1Q2': 0.439, 'WAI-SR': 0.451, 'CSQ-8': 0.452, 'MI-SAT': 0.451, 'MITI': 0.444}
# PTO_LA0: PC1 = 90.7%  loadings={'Q1Q2': 0.442, 'WAI-SR': 0.454, 'CSQ-8': 0.452, 'MI-SAT': 0.455, 'MITI': 0.432}
# PTO_LA5: PC1 = 91.6%  loadings={'Q1Q2': 0.437, 'WAI-SR': 0.452, 'CSQ-8': 0.452, 'MI-SAT': 0.454, 'MITI': 0.441}

# %% [markdown]
# ## 3 · Heterogeneity by true persona  `[EVAL]`
# **Purpose.** Does the gain depend on who the patient is? Q1+Q2 across iterations split by the recovered
# persona traits (cooperation level, problem). Exploratory.

# %%
for char in ["cooperation_level", "problem"]:
    for arm in sorted(S.SCORES.arm.unique()):
        d = S.SCORES[(S.SCORES.arm == arm) & (S.SCORES.questionnaire == "Q1Q2")]
        if d.iteration.nunique() < 3 or char not in d.columns:
            continue
        fig, ax = plt.subplots(figsize=(7.5, 4.2))
        sns.lineplot(d, x="iteration", y="score", hue=char, marker="o", palette="viridis", ax=ax)
        ax.set_title(f"Q1Q2 by {char} (true persona) — {arm}"); fig.tight_layout()
        exp3.save_fig(fig, f"heterogeneity_{char}_{arm}", caption=f"{arm} Q1+Q2 across iterations split by true patient {char}."); plt.show()

# %% [markdown]
# ## 4 · Session end + length  `[EVAL]`
# **Purpose.** Mean conversation length across iterations + how sessions terminate. **Read:** rising
# length tracks the advice drift; the end-reason mix is a degeneration health-check.

# %%
TEXT = behavior.text_metrics(S.ARMS, attach_persona=False)
fig, ax = plt.subplots(figsize=(8, 4))
sns.lineplot(TEXT, x="iteration", y="conv_len", hue="arm", palette=figures.arm_palette(sorted(TEXT.arm.unique())), marker="o", ax=ax)
ax.set_title("Mean conversation length (utterances)"); plt.show()
rows = []
for a in S.ARMS:
    for k in a.iters:
        cdir = a.conv_dir(k)
        for fn in (os.listdir(cdir) if cdir and os.path.isdir(cdir) else []):
            if fn.startswith("conversation_") and fn.endswith(".csv"):
                try: dd = pd.read_csv(os.path.join(cdir, fn))
                except Exception: continue
                rows.append({"arm": a.label, "ended_by": str(dd["session_ended_by"].iloc[0]) if "session_ended_by" in dd else "NA"})
if rows:
    display(pd.DataFrame(rows).groupby(["arm", "ended_by"]).size().rename("n").reset_index()
            .pivot_table(index="arm", columns="ended_by", values="n", fill_value=0))
# Out:
# ended_by    nan  patient  therapist
# arm
# GRPO_LA0  134.0    439.0        3.0
# GRPO_LA5   61.0    128.0        3.0
# PTO_LA0   178.0    871.0        7.0
# PTO_LA5   127.0    349.0        4.0

# %% [markdown]
# ## 5 · Persona-matched transcripts  `[EVAL]`
# **Purpose.** The same patient persona's conversation early / mid / late per arm — the qualitative drift
# in actual words (true-persona recovery makes the match exact across the per-iteration shuffle).

# %%
from exp3.personas import persona_order
def file_of_persona(seed, k, pid, n=96): return persona_order(seed, k, n).index(pid)
PERSONA = 0
print("persona", PERSONA, "=", exp3.canonical_personas().loc[PERSONA].to_dict(), "\n")
for arm in S.ARMS:
    iters = arm.iters
    pick = sorted(set([iters[0], iters[len(iters) // 2], iters[-1]]))
    print(f"\n############  {arm.label}  ############")
    for k in pick:
        cdir = arm.conv_dir(k)
        if not cdir: continue
        fi = file_of_persona(arm.seed, k, PERSONA)
        fp = os.path.join(cdir, f"conversation_{fi}.csv")
        if not os.path.exists(fp): continue
        d = pd.read_csv(fp); th = d[d.role == "therapist"]["conversation"].astype(str).tolist()
        print(f"==== {arm.label} model_iter_{k} (conv_{fi}) — {len(th)} therapist turns ====")
        for t in th[1:4]:
            print("   •", " ".join(t.split())[:240]); print()
# Out:
# persona 0 = {'gender': 'Male', 'age_value': 27, 'problem': 'Smoking', 'problem_time': 'FewMonths', 'tried_to_solve': 'Never', 'cooperation_level': 'Low'}
#
#
# ############  PTO_LA0  ############
# ==== PTO_LA0 model_iter_0 (conv_14) — 10 therapist turns ====
#    • I can understand that. Let's talk about your goals. What's the point of this session?
#
#    • OK, so why don't we start by talking about what it is you enjoy about smoking?
#
#    • I can see that. So what do you enjoy about it? Are there any specific activities you like to do?
#
# ==== PTO_LA0 model_iter_5 (conv_54) — 8 therapist turns ====
#    • Oh, right, well that’s ok. Let’s talk about what motivates you to want to stop smoking. What do you see as the biggest barrier to doing so?
#
#    • That’s fair. So, how do you want to approach this conversation? What would you like to achieve from our time together?
#
#    • Oh, I totally understand. I can relate to that. I’m here to help you understand why quitting smoking is important and how you can do it. We can start by exploring the different reasons why you may want to stop smoking. How can we make that
#
# ==== PTO_LA0 model_iter_10 (conv_4) — 11 therapist turns ====
#    • Oh, I see. I understand where you're coming from. It's great that you're willing to explore this with me. I won't pressure you to do anything you're not comfortable with. We can work at your own pace and focus on what's most important for y
#
#    • No worries, I'm not here to judge your reasons or tell you what to do. You have every right to decide what works for you. My job is to offer you a safe space to express yourself and explore your experiences. I'm not here to put pressure on
#
#    • I hear you. You're not alone in feeling like this. It can be challenging to navigate the unknown. We can start with simple steps that make sense for you. One idea could be writing down your feelings and needs. You can use this as a roadmap
#
#
# ############  PTO_LA5  ############
# ==== PTO_LA5 model_iter_0 (conv_14) — 12 therapist turns ====
#    • I see. Let's start with a few background questions. Why did you start smoking? How often do you smoke? How do you feel about it? Do you smoke with others? Is it something you do on a daily basis? Are there specific situations that make you
#
#    • You don't seem like someone who could benefit from a little motivational guidance. Have you ever tried anything like that before?
#
#    • You should listen to your body. Try to figure out why you smoke and what you can do to change that. What have you tried so far? How did those efforts go?
#
# ==== PTO_LA5 model_iter_3 (conv_15) — 12 therapist turns ====
#    • Okay, let's talk about what you're feeling about this smoking. Why are you here? What's holding you back from making better choices?
#
#    • What about your family? Do they feel strongly about it? Are there any reasons you want to quit that are important to you? Can you talk about those? It's helpful to understand your reasons for smoking.
#
#    • Oh, I see. Can you talk about what makes you feel good when you smoke? What does it give you? How does it make you feel? It's important to know what you're missing.
#
#
# ############  GRPO_LA0  ############
# ==== GRPO_LA0 model_iter_0 (conv_14) — 17 therapist turns ====
#    • I can understand that. Let's talk about your goals. What's the point of this session?
#
#    • Alright, that's fair. I'm not here to judge you or anything. Let's talk about how you think this session might go.
#
#    • Alright, I see. Let's try to focus on what you're really here for, which is to think about quitting smoking. The other things you're saying about it just sound more like a way to talk than a way to actually quit. Let's try to talk about tha
#
# ==== GRPO_LA0 model_iter_3 (conv_15) — 19 therapist turns ====
#    • Okay, well I'm happy that you're here. Let's start with a few questions to get to know you. First, can you tell me a little bit about your reasons for smoking?
#
#    • That's fine, let's move on. Do you have any goals for smoking cessation?
#
#    • That's understandable. Let's focus on the present and your current situation. How do you feel about your current smoking habit?
#
# ==== GRPO_LA0 model_iter_5 (conv_54) — 25 therapist turns ====
#    • Great, that’s understandable. Let’s take some time to think about what motivates you to want to quit. What are some of the things that you’re doing right now that might make it easier for you to make a change? Are there any things that you
#
#    • That’s a fair question. It can be difficult to see the benefits of making a change when you’re in the midst of a habit, especially when you’ve been doing it for so long. However, by understanding your current situation and exploring differe
#
#    • I understand that it can be challenging to believe in the power of change, especially when you’re feeling overwhelmed or uncertain. That’s why I want to approach this conversation from a more practical and realistic perspective. Here are so
#
#
# ############  GRPO_LA5  ############
# ==== GRPO_LA5 model_iter_0 (conv_14) — 9 therapist turns ====
#    • I'll try and make this easy for you. I'm here to help you quit smoking. I understand that this is a difficult task and I'll do my best to make it as easy as possible for you. What do you think your main challenges are?
#
#    • I understand, but I’m here to help you quit. So, I’ll need to understand why you want to quit, and the challenges you face. Do you feel like you could easily give up smoking?
#
#    • I understand, but I’m still here. We need to discuss your motivation. Why do you think you need to quit?
#
# ==== GRPO_LA5 model_iter_1 (conv_23) — 13 therapist turns ====
#    • Hey James, thank you for your first session with me. I’m glad to hear that you’ve decided to quit smoking. And while you’re still in the process of quitting, I strongly suggest that you take time to understand what is behind your desire to
#
#    • I’m really sorry to hear that. But please, allow me to help you understand your desire to smoke better. I’d like to start by explaining the physical health consequences of smoking. These consequences are the direct result of the toxic chemi
#
#    • I don’t think that’s how quitting works. I think quitting is a choice that you make for yourself. And it’s important to remember that you’re the only one who can make that choice. I’m here to help you understand why you want to quit, and ho

# %% [markdown]
# ## 6 · How to read this notebook
# - The **affirmation-drift** signature (B6_AF + turn length up, B3_Q down, §1) is the warmth-over-skill flag — compare PTO vs GRPO onset at matched late iters.
# - A dominant **PC1** (§2) means "all rubrics up" is one latent factor, weak multi-skill evidence.
# - **Heterogeneity** (§3) shows which personas benefit; **transcripts** (§5) are the ground truth.
# - _(Reward faithfulness → `4`; exact stats → `6`.)_
